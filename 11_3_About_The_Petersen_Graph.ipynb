# %% [markdown]
# <a href="https://colab.research.google.com/github/paulpowell1/cse380-notebooks/blob/master/11_3_About_The_Petersen_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About The Petersen Graph
# ## Class Directed Learning
# ### Due: Tuesday, 16 March 2021, 11:59 pm

# %% [markdown]
# ## TODO Explore and Wonder

# %% [markdown]
# The Petersen graph is described as the complement of the line graph of $K_5$.
#
# Draw each step of this construction using any graph-drawing tools in your toolbox.
#
# Teach one another how to use the tools you each have.

# %% [markdown]
# This is a K5 graph which is not planar. It doesn't follow Eular's relationship.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# below is the peterson graph and points that eventually add together.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
